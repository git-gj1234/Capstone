# %% [markdown]
# ⚙️ Config-Driven Legal RAG Indexer with LanceDB + Legal-BERT

# %%
import os
import re
import fitz
import lancedb
import numpy as np
from typing import List, Dict
from lancedb.pydantic import Vector, LanceModel
from legalbert_embedder import LegalBERTEmbedder
import csv

# %%
# 🔧 CONFIGURATION
config = {
    "model_name": "nlpaueb/legal-bert-base-uncased",
    "comp_pdf": "CompaniesAct.pdf",
    "bank_pdf": "BankruptcyAct.pdf",
    "db_path": "./Data",

    # Table names for LanceDB
    "comp_table": "CompaniesAct",
    "bank_table": "BankruptcyAct",
    "constitution_table": "IndianConstitution",

    # CSV path for Indian Constitution
    "constitution_csv": "Indian_Constitution.csv"
}

# %%
def load_pdf_text(path: str) -> List[str]:
    doc = fitz.open(path)
    return [page.get_text() for page in doc]

# %%
def extract_sections_bankruptcy_act(full_text: str, config: Dict) -> List[Dict]:
    section_pattern = re.compile(r"(?i)(SECTION\s*\d+[A-Z]?(?:\.\d+)?(?:[A-Z]*)?)")
    part_pattern = re.compile(r"(?i)^\s*(PART\s+[A-Z]+.*?)$", re.MULTILINE)
    chapter_pattern = re.compile(r"(?i)^\s*(CHAPTER\s+[IVXLC]+.*?)$", re.MULTILINE)

    # Find headings
    section_matches = list(section_pattern.finditer(full_text))
    part_matches = list(part_pattern.finditer(full_text))
    chapter_matches = list(chapter_pattern.finditer(full_text))

    # Mapping start locations
    part_map = {m.start(): m.group(1).strip() for m in part_matches}
    chapter_map = {m.start(): m.group(1).strip() for m in chapter_matches}
    part_starts = sorted(part_map.keys())
    chapter_starts = sorted(chapter_map.keys())

    chunks = []
    for i, match in enumerate(section_matches):
        start = match.start()
        end = section_matches[i+1].start() if i+1 < len(section_matches) else len(full_text)
        chunk_text = full_text[start:end].strip()
        section_title = match.group(1).strip()

        # Find closest PART
        part_title = None
        for p_start in reversed(part_starts):
            if p_start <= start:
                part_title = part_map[p_start]
                break

        # Find closest CHAPTER
        chapter_title = None
        for ch_start in reversed(chapter_starts):
            if ch_start <= start:
                chapter_title = chapter_map[ch_start]
                break

        chunks.append({
            "id": f"bankruptcy_section_{i}",
            "chunk": chunk_text,
            "section_title": section_title,
            "chapter_title": chapter_title,
            "part_title": part_title,
            "page": None,
            "source": "Bankruptcy Act",
        })

    return chunks

# %%
def extract_sections_with_meta_comp(full_text: str, config: Dict) -> List[Dict]:
    section_pattern = re.compile(r"(?i)(SECTION\s*\d+[A-Z]?(?:\.\d+)?[A-Z]*)")
    chapter_pattern = re.compile(r"(?i)^\s*(CHAPTER\s+[IVXLC]+.*?)$", re.MULTILINE)

    matches = list(section_pattern.finditer(full_text))
    chapter_matches = list(chapter_pattern.finditer(full_text))

    # Map chapter start positions to titles
    chapter_map = {m.start(): m.group(1).strip() for m in chapter_matches}
    chapter_starts = sorted(chapter_map.keys())

    chunks = []
    for i, match in enumerate(matches):
        start = match.start()
        end = matches[i + 1].start() if i + 1 < len(matches) else len(full_text)
        chunk_text = full_text[start:end].strip()
        section_title = match.group(1).strip()

        # Get closest preceding chapter
        chapter_title = None
        for ch_start in reversed(chapter_starts):
            if ch_start <= start:
                chapter_title = chapter_map[ch_start]
                break

        chunks.append({
            "id": f"section_{i}",
            "chunk": chunk_text,
            "section_title": section_title,
            "chapter_title": chapter_title,
            "page": None,
            "source": "Companies Act",
        })

    return chunks

# %%
def create_lancedb_index_constitution(chunks: List[Dict], embeddings: np.ndarray, db_path: str, table_name: str):
    class ConstitutionArticle(LanceModel):
        id: str
        chunk: str
        embedding: Vector(768)
        section_title: str
        chapter_title: str
        page: int = None
        source: str

    try:
        if not os.path.exists(db_path):
            os.makedirs(db_path)

        db = lancedb.connect(db_path)

        for i in range(len(chunks)):
            chunks[i]["embedding"] = embeddings[i].tolist()

        table = db.create_table(table_name, data=chunks, schema=ConstitutionArticle, mode="overwrite")
        return table

    except Exception as e:
        print(f"❌ Error creating LanceDB index for Constitution: {e}")
        return None

# %%
def create_lancedb_index_bankruptcy(chunks: List[Dict], embeddings: np.ndarray, db_path: str, table_name: str):
    class Document1(LanceModel):
        id: str
        chunk: str
        embedding: Vector(768)
        part_title: str = None
        chapter_title: str = None
        section_title: str = None
        page: int
        source: str
    if not os.path.exists(db_path): os.makedirs(db_path)
    db = lancedb.connect(db_path)
    for i in range(len(chunks)):
        chunks[i]["embedding"] = embeddings[i].tolist()
    table = db.create_table(table_name, data=chunks, schema=Document1, mode="overwrite")
    return table

# %%
def create_lancedb_index_company(chunks: List[Dict], embeddings: np.ndarray, db_path: str, table_name: str):
    class Document2(LanceModel):
        id: str
        chunk: str
        embedding: Vector(768)
        section_title: str = None
        chapter_title: str = None
        page: int = None
        source: str
    if not os.path.exists(db_path): os.makedirs(db_path)
    db = lancedb.connect(db_path)
    for i in range(len(chunks)):
        chunks[i]["embedding"] = embeddings[i].tolist()
    table = db.create_table(table_name, data=chunks, schema=Document2, mode="overwrite")
    return table

# %%
def load_constitution_articles(file_path: str) -> List[Dict]:
    articles = []
    try:
        with open(file_path, newline='', encoding='utf-8') as csvfile:
            reader = csv.DictReader(csvfile)
            for i, row in enumerate(reader):
                articles.append({
                    "id": f"constitution_article_{i}",
                    "chunk": row["article_desc"].strip(),
                    "section_title": row["article_id"].strip(),
                    "chapter_title": "Indian Constitution",
                    "page": None,
                    "source": "Indian Constitution"
                })
        return articles
    except FileNotFoundError:
        print(f"❌ CSV file not found: {file_path}")
    except KeyError as ke:
        print(f"❌ Missing column in CSV: {ke}")
    except Exception as e:
        print(f"❌ Error loading Constitution articles: {e}")
    return []

# %%
def index_constitution_articles(config: Dict) -> None:
    try:
        model = LegalBERTEmbedder()
        chunks = load_constitution_articles(config["constitution_csv"])

        if not chunks:
            print("⚠️ No articles loaded. Skipping indexing.")
            return
        print(f"Extracted {len(chunks)} articles in the Indian Constitution CSV.")
        embeddings = model.encode([c["chunk"] for c in chunks])
        result = create_lancedb_index_constitution(chunks, embeddings, config["db_path"], config["constitution_table"])

        if result:
            print("✅ LanceDB index created for Indian Constitution.")
    except Exception as e:
        print(f"❌ Error indexing Constitution articles: {e}")

# %%
def index_bankruptcy_act(config: Dict) -> None:
    model = LegalBERTEmbedder()
    pages = load_pdf_text(config["bank_pdf"])
    full_text = "\n".join(pages)
    chunks = extract_sections_bankruptcy_act(full_text, config)
    print(f"Extracted {len(chunks)} semantic sections.")
    embeddings = model.encode([c["chunk"] for c in chunks])
    create_lancedb_index_bankruptcy(chunks, embeddings, config["db_path"], config["bank_table"])
    print("✅ LanceDB index created for Bankruptcy Act.")

# %%
# RUN PIPELINE
def index_company_act(config: Dict) -> None:
    model = LegalBERTEmbedder()
    pages = load_pdf_text(config["comp_pdf"])
    full_text = "\n".join(pages)
    chunks = extract_sections_with_meta_comp(full_text, config)
    print(f"Extracted {len(chunks)} semantic sections.")
    embeddings = model.encode([c["chunk"] for c in chunks])
    create_lancedb_index_company(chunks, embeddings, config["db_path"], config["comp_table"])
    print("✅ LanceDB index created for Company Act.")

# %%
index_bankruptcy_act(config)
index_company_act(config)
index_constitution_articles(config)
# Out:
# Extracted 507 semantic sections.
# ✅ LanceDB index created for Bankruptcy Act.
# Extracted 566 semantic sections.
# ✅ LanceDB index created for Company Act.
# 📄 Found 454 articles in the Indian Constitution CSV.
# ✅ LanceDB index created for Indian Constitution.

# %%
import lancedb
from legalbert_embedder import LegalBERTEmbedder
import pandas as pd
import os
import re
import fitz
import lancedb
import numpy as np
from typing import List, Dict
from lancedb.pydantic import Vector, LanceModel
import csv

# %%
# 🔧 CONFIGURATION
config = {
    "model_name": "nlpaueb/legal-bert-base-uncased",
    "comp_pdf": "CompaniesAct.pdf",
    "bank_pdf": "BankruptcyAct.pdf",
    "db_path": "./Data",
    # Table names for LanceDB
    "comp_table": "CompaniesAct",
    "bank_table": "BankruptcyAct",
    "constitution_table": "IndianConstitution",
    # CSV path for Indian Constitution
    "constitution_csv": "Indian_Constitution.csv"
}

# %%
class LegalRetriever:
    def __init__(self, top_k: int = 5):
        self.model = LegalBERTEmbedder()
        self.top_k = top_k
        self.dbs = {}

    def _get_table(self, db_path: str, table_name: str):
        if db_path not in self.dbs:
            try:
                self.dbs[db_path] = lancedb.connect(db_path)
            except Exception as e:
                raise RuntimeError(f"Failed to connect to DB at {db_path}: {str(e)}")
        try:
            return self.dbs[db_path].open_table(table_name)
        except Exception as e:
            raise RuntimeError(f"Failed to open table '{table_name}' in DB '{db_path}': {str(e)}")

    def query_multiple(self, query_text: str, tables: list[dict]) -> list:
        try:
            query_vec = self.model.encode([query_text])[0].tolist()
        except Exception as e:
            raise RuntimeError(f"Failed to embed query: {str(e)}")

        all_results = []

        for tbl in tables:
            try:
                table = self._get_table(tbl["db_path"], tbl["table_name"])
                df = table.search(query_vec).limit(self.top_k).to_df()
                all_results.append(df)
            except Exception as e:
                print(f"Warning: Failed to query table '{tbl['table_name']}' in DB '{tbl['db_path']}': {str(e)}")
        if not all_results:
            return []

        try:
            merged_df = pd.concat(all_results, ignore_index=True)
            if "_distance" in merged_df.columns:
                merged_df = merged_df.sort_values(by="_distance", ascending=True)
        except Exception as e:
            raise RuntimeError(f"Failed to process merged results: {str(e)}")
        print(merged_df)
        return [
            {
                "id": row.get("id"),
                "chunk": row.get("chunk"),
                "part_title": row.get("part_title"),
                "chapter_title": row.get("chapter_title"),
                "section_title": row.get("section_title"),
                "page": row.get("page"),
                "source": row.get("source"),
                "score": row.get("_distance")
            }
            for _, row in merged_df.iterrows()
        ][:self.top_k]

# %%
retriever = LegalRetriever(top_k=5)
def query_legal_documents(query: str) -> List[Dict]:
    tables = [
        {"db_path": config["db_path"], "table_name": config["comp_table"]},
        {"db_path": config["db_path"], "table_name": config["bank_table"]},
        {"db_path": config["db_path"], "table_name": config["constitution_table"]}
    ]
    return retriever.query_multiple(query, tables)

# %%
x = query_legal_documents(query = """Power of company to purchase its own securities""")
print("-"*50)
for i in x:
    print("-+"*20)
    print(i["chunk"])
# Out:
#                           id  \
# 0                section_291
# 5     bankruptcy_section_294
# 1                section_159
# 2                section_421
# 6     bankruptcy_section_268
# 3                section_455
# 10  constitution_article_158
# 11  constitution_article_421
# 4                section_506
# 12  constitution_article_223
# 7     bankruptcy_section_230
# 13  constitution_article_112
# 14  constitution_article_440
# 8       bankruptcy_section_4
# 9     bankruptcy_section_430
#
#                                                 chunk  \
# 0   section 206 and other books and papers of the ...
# 5   section 7; \n \n(d) the form and manner in whi...
# 1   section 124 unless the company is authorised b...
# 2   section 378B; \n\n205 \n \n(d) the names and a...
# 6   section 178, such surplus shall be paid to the...
# 3   section 389 as they \napply to prospectus issu...
# 10  Form of accounts of the Union and of the State...
# 11  Rights and privileges of Rulers of Indian Stat...
# 4   section 40, \nprovided that the rate per cent....
# 12  High Courts to be courts of record Every High ...
# 7   section 129; or \n(ii) the application for ban...
# 13  Salaries and allowances of members Members of ...
# 14  Special provision with respect to the State of...
# 8   section 45-I of the Reserve Bank of India \nAc...
# 9   section 246) \n \nAMENDMENT TO THE CENTRAL EXC...
#
#                           section_title        chapter_title  page  \
# 0                           section 206          CHAPTER XIV   NaN
# 5                             section 7          CHAPTER VII   NaN
# 1                           section 124         CHAPTER VIII   NaN
# 2                          section 378B          CHAPTER XXI   NaN
# 6                           section 178            CHAPTER V   NaN
# 3                           section 389         CHAPTER XXII   NaN
# 10   Article 150 of Indian Constitution  Indian Constitution   NaN
# 11   Article 362 of Indian Constitution  Indian Constitution   NaN
# 4                            section 40         CHAPTER XXIX   NaN
# 12   Article 215 of Indian Constitution  Indian Constitution   NaN
# 7                           section 129           CHAPTER IV   NaN
# 13   Article 106 of Indian Constitution  Indian Constitution   NaN
# 14  Article 371I of Indian Constitution  Indian Constitution   NaN
# 8                            section 45                 None   NaN
# 9                           section 246          CHAPTER VII   NaN
#
#                  source                                          embedding  \
# 0         Companies Act  [-0.17425247, -0.0024634176, -0.068689525, -0....
# 5        Bankruptcy Act  [-0.22273383, -0.07348666, 0.16795471, 0.05958...
# 1         Companies Act  [-0.090899445, -0.0784394, 0.13859923, -0.1348...
# 2         Companies Act  [-0.13633037, 0.0902718, 0.17048965, 0.0206937...
# 6        Bankruptcy Act  [-0.2355237, -0.091865174, 0.27142206, -0.0039...
# 3         Companies Act  [-0.11091849, -0.13610631, 0.0725136, 0.088120...
# 10  Indian Constitution  [-0.08163664, 0.09967568, 0.07979407, 0.118934...
# 11  Indian Constitution  [-0.17759468, -0.076218575, 0.055822544, -0.04...
# 4         Companies Act  [-0.20731863, 0.03746533, 0.10317902, -0.04302...
# 12  Indian Constitution  [-0.019499272, 0.079615444, 0.069918774, -0.08...
# 7        Bankruptcy Act  [-0.18381332, -0.12457362, 0.044169284, 0.0017...
# 13  Indian Constitution  [-0.10333395, 0.13814726, 0.13950208, 0.066935...
# 14  Indian Constitution  [-0.122591555, 0.022387592, 0.22406206, 0.0239...
# 8        Bankruptcy Act  [-0.16848695, 0.07090413, 0.07132204, -0.02135...
# 9        Bankruptcy Act  [-0.031930596, -0.06899315, -0.063327715, -0.0...
#
#     _distance             part_title
# 0   35.901127                    NaN
# 5   36.002338                 PART V
# 1   36.804554                    NaN
# 2   37.284176                    NaN
# 6   37.295223  part of the debt; and
# 3   37.437859                    NaN
# 10  37.495766                    NaN
# 11  37.574688                    NaN
# 4   37.818329                    NaN
# 12  38.068722                    NaN
# 7   38.581123  part of the debt; and
# 13  38.582443                    NaN
# 14  38.606087                    NaN
# 8   38.888382                 PART I
# 9   38.980419                 PART V
# --------------------------------------------------
# -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+
# section 206 and other books and papers of the company under
# -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+
# section 7;
#
# (d) the form and manner in which demand notice may be made and the manner
# of delivery thereof to the corporate debtor under sub-section (1) of
# -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+
# section 124 unless the company is authorised by the registered holder of such shares in writing to pay
# such dividend to the transferee specified in such instrument of transfer; and
# (b) keep in abeyance in relation to such shares, any offer of rights shares under clause (a) of
# sub-section (1) of
# -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+
# section 378B;
#
# 205
#
# (d) the names and addresses of the persons who have subscribed to the memorandum;
# (e) the amount of share capital with which the Producer Company is to be registered and division
# thereof into shares of a fixed amount;
# (f) the names, addresses and occupations of the subscribers being producers, who shall act as the
# first directors in accordance with sub-section (2) of
# -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+
# section 178, such surplus shall be paid to the legal representatives of the estate of the deceased
# bankrupt or dealt with in such manner as may be prescribed.
# 171.  Proof of debt. -
#
# (1) The bankruptcy trustee shall give notice to each of the creditors to submit proof of
# debt within fourteen days of preparing the list of creditors under
# /tmp/ipykernel_29459/402833883.py:29: UnsupportedWarning: to_df is unsupported as of 0.4.0. Use to_pandas() instead
#   df = table.search(query_vec).limit(self.top_k).to_df()

# %%
print("-"*50)
print(query_legal_documents(query = "What are the requirements for corporate insolvency resolution under the Companies Act and the Insolvency and Bankruptcy Code?"))
# Out:
# --------------------------------------------------
#                           id  \
# 5     bankruptcy_section_389
# 6      bankruptcy_section_74
# 7     bankruptcy_section_317
# 8      bankruptcy_section_82
# 9      bankruptcy_section_80
# 0                section_204
# 1                section_561
# 2                section_480
# 3                section_144
# 4                section_258
# 10  constitution_article_359
# 11  constitution_article_254
# 12  constitution_article_378
# 13   constitution_article_34
# 14  constitution_article_351
#
#                                                 chunk  \
# 5   section 196; \n(zv) the intervals in which the...
# 6   section 62 or such an \nappeal is not time bar...
# 7   section 130; \n\n \n \n \n143 \n \n \n \n \n(w...
# 8   section 30, it shall by order approve the reso...
# 9   section 29A as amended by the Insolvency and \...
# 0   section 3 of the \nChartered Accountants Act, ...
# 1   section 197. \n3[(b) where the company— \n(i) ...
# 2   section 10E of the \nCompanies Act, 1956 (1 of...
# 3   section 179 in the ordinary course of its busi...
# 4   section 134 shall disclose the composition of ...
# 10  Appointment of authority for carrying out the ...
# 11  Power of President to make regulations for cer...
# 12  Tribunals for other matters\n(1) The appropria...
# 13  Remedies for enforcement of rights conferred b...
# 14  Suits and proceedings\n(1) The Governor of Ind...
#
#                           section_title  \
# 5                           section 196
# 6                            section 62
# 7                           section 130
# 8                            section 30
# 9                           section 29A
# 0                             section 3
# 1                           section 197
# 2                           section 10E
# 3                           section 179
# 4                           section 134
# 10   Article 307 of Indian Constitution
# 11   Article 240 of Indian Constitution
# 12  Article 323B of Indian Constitution
# 13    Article 32 of Indian Constitution
# 14   Article 300 of Indian Constitution
#
#                                         chapter_title  page  \
# 5                                         CHAPTER VII   NaN
# 6                                          CHAPTER II   NaN
# 7                                         CHAPTER VII   NaN
# 8                                          CHAPTER II   NaN
# 9                                          CHAPTER II   NaN
# 0                                           CHAPTER X   NaN
# 1                                        CHAPTER XXIX   NaN
# 2   Chapter VI of the Finance Act, 2017, shall con...   NaN
# 3                                         CHAPTER VII   NaN
# 4                                         CHAPTER XII   NaN
# 10                                Indian Constitution   NaN
# 11                                Indian Constitution   NaN
# 12                                Indian Constitution   NaN
# 13                                Indian Constitution   NaN
# 14                                Indian Constitution   NaN
#
#                  source                                          embedding  \
# 5        Bankruptcy Act  [-0.1743483, 0.18421967, 0.22463436, 0.0136592...
# 6        Bankruptcy Act  [-0.27778214, 0.08555613, 0.24868771, -0.07245...
# 7        Bankruptcy Act  [-0.3596237, 0.12820435, 0.2145017, -0.1723983...
# 8        Bankruptcy Act  [-0.09737464, 0.103483036, 0.2476347, -0.14856...
# 9        Bankruptcy Act  [-0.28561974, 0.049487416, 0.31080756, -0.0145...
# 0         Companies Act  [-0.26554003, 0.16485201, 0.111373775, -0.0323...
# 1         Companies Act  [-0.2850526, 0.081864506, 0.22437128, -0.12028...
# 2         Companies Act  [-0.2584305, 0.21179238, 0.12376928, -0.243688...
# 3         Companies Act  [-0.29690117, 0.19978642, 0.16465601, -0.01841...
# 4         Companies Act  [-0.21195893, 0.15381512, 0.11336289, -0.06637...
# 10  Indian Constitution  [-0.12035664, 0.20124969, 0.2124305, -0.128802...
# 11  Indian Constitution  [-0.089093424, 0.2505223, 0.122047625, -0.0301...
# 12  Indian Constitution  [-0.08238028, 0.2228377, 0.17783426, -0.167602...
# 13  Indian Constitution  [-0.052959718, 0.38759044, 0.17278905, -0.0779...
# 14  Indian Constitution  [0.066049986, 0.16782159, 0.02598984, -0.06977...
#
#     _distance part_title
# 5   19.476749     PART V
# 6   19.494644    PART II
# 7   19.833282     PART V
# 8   20.082420    PART II
# 9   20.151451    PART II
# 0   21.776508        NaN
# 1   21.865459        NaN
# 2   22.435829        NaN
# 3   22.581123        NaN
# 4   22.878614        NaN
# 10  24.808594        NaN
# 11  24.936928        NaN
# 12  25.226744        NaN
# 13  25.459917        NaN
# 14  25.642132        NaN
# [{'id': 'bankruptcy_section_389', 'chunk': 'section 196; \n(zv) the intervals in which the periodic study, research and audit of the functioning \nand performance of the insolvency professional agencies, insolvency professionals and \ninformation utilities under clause (r), and mechanism for disposal of assets under clause \n(t), of sub-section (1) of', 'part_title': 'PART V', 'chapter_title': 'CHAPTER VII', 'section_title': 'section 196', 'page': nan, 'source': 'Bankruptcy Act', 'score': 19.476749420166016}, {'id': 'bankruptcy_section_74', 'chunk': 'section 62 or such an \nappeal is not time barred under any provision of law for the time being in force; or \n                (iii) where a legal proceeding has been initiated in any court against the decision of \nthe Adjudicating Authority in respect of a resolution plan;]  \n(c) provides for the management of the affairs of the Corporate debtor after \napproval of the resolution plan;  \n(d) The implementation and supervision of the resolution plan;  \n(e) does not contravene any of the provisions of the law for the time being in force \n(f) confirms to such other requirements as may be specified by the Board. \n 1[Explanation. — For the purposes of clause (e), if any approval of shareholders is required under \nthe Companies Act, 2013(18 of 2013) or any other law for the time being in force for the \nimplementation of actions under the resolution plan, such approval shall be deemed to have been given \nand it shall not be a contravention of that Act or law.]  \n(3) The resolution professional shall present to the committee of creditors for its \napproval such resolution plans which confirm the conditions referred to in sub-section (2). \n2[(4) The committee of creditors may approve a resolution plan by a vote of not less \nthan 3[sixty-six] per cent. of voting share of the financial creditors, after considering its \nfeasibility and viability, 4[the manner of distribution proposed, which may take into \naccount the order of priority amongst creditors as laid down in sub-section (1) of', 'part_title': 'PART II', 'chapter_title': 'CHAPTER II', 'section_title': 'section 62', 'page': nan, 'source': 'Bankruptcy Act', 'score': 19.494644165039062}, {'id': 'bankruptcy_section_317', 'chunk': 'section 130; \n\n \n \n \n143 \n \n \n \n \n(w) the manner of sending details of the claims to the bankruptcy trustee and \nother information under sub-sections (1) and (2) of', 'part_title': 'PART V', 'chapter_title': 'CHAPTER VII', 'section_title': 'section 130', 'page': nan, 'source': 'Bankruptcy Act', 'score': 19.833282470703125}, {'id': 'bankruptcy_section_82', 'chunk': 'section 30, it shall by order approve the resolution plan \nwhich shall be binding on the corporate debtor and its employees, members, creditors, \n2[including the Central Government, any State Government or any local authority to whom \na debt in respect of the payment of dues arising under any law for the time being in force, \nsuch as authorities to whom statutory dues are owed,] guarantors and other stakeholders \ninvolved in the resolution plan. \n \n1 Ins. by Act. No. 26 of 2018, sec. 23 (iii) (b) (w.e.f. 6-6-2018). \n2 Ins. by Act No. 26 of 2019, sec. 7 (w.e.f. 16-8-2019). \n\n \n \n \n40 \n \n \n \n \n1[Provided that the Adjudicating Authority shall, before passing an order for approval of \nresolution plan under this sub-section, satisfy that the resolution plan has provisions for its \neffective implementation.] \n \n(2) Where the Adjudicating Authority is satisfied that the resolution plan does not \nconfirm to the requirements referred to in sub-section (1), it may, by an order, reject the \nresolution plan. \n(3)  After the order of approval under sub-section (1), - \n(a) the moratorium order passed by the Adjudicating Authority under', 'part_title': 'PART II', 'chapter_title': 'CHAPTER II', 'section_title': 'section 30', 'page': nan, 'source': 'Bankruptcy Act', 'score': 20.082420349121094}, {'id': 'bankruptcy_s ...
# /tmp/ipykernel_29459/402833883.py:29: UnsupportedWarning: to_df is unsupported as of 0.4.0. Use to_pandas() instead
#   df = table.search(query_vec).limit(self.top_k).to_df()

# %%
query_legal_documents(query = "What are the requirements for corporate insolvency resolution under the Companies Act and the Insolvency and Bankruptcy Code?")
# Out:
#                        id                                              chunk  \
# 5  bankruptcy_section_389  section 196; \n(zv) the intervals in which the...
# 6   bankruptcy_section_74  section 62 or such an \nappeal is not time bar...
# 7  bankruptcy_section_317  section 130; \n\n \n \n \n143 \n \n \n \n \n(w...
# 8   bankruptcy_section_82  section 30, it shall by order approve the reso...
# 9   bankruptcy_section_80  section 29A as amended by the Insolvency and \...
# 0             section_204  section 3 of the \nChartered Accountants Act, ...
# 1             section_561  section 197. \n3[(b) where the company— \n(i) ...
# 2             section_480  section 10E of the \nCompanies Act, 1956 (1 of...
# 3             section_144  section 179 in the ordinary course of its busi...
# 4             section_258  section 134 shall disclose the composition of ...
#
#   section_title                                      chapter_title  page  \
# 5   section 196                                        CHAPTER VII   NaN
# 6    section 62                                         CHAPTER II   NaN
# 7   section 130                                        CHAPTER VII   NaN
# 8    section 30                                         CHAPTER II   NaN
# 9   section 29A                                         CHAPTER II   NaN
# 0     section 3                                          CHAPTER X   NaN
# 1   section 197                                       CHAPTER XXIX   NaN
# 2   section 10E  Chapter VI of the Finance Act, 2017, shall con...   NaN
# 3   section 179                                        CHAPTER VII   NaN
# 4   section 134                                        CHAPTER XII   NaN
#
#            source                                          embedding  \
# 5  Bankruptcy Act  [-0.1743477, 0.1842196, 0.22463417, 0.01365938...
# 6  Bankruptcy Act  [-0.27778187, 0.0855561, 0.24868734, -0.072453...
# 7  Bankruptcy Act  [-0.35962388, 0.12820426, 0.21450107, -0.17239...
# 8  Bankruptcy Act  [-0.09737422, 0.10348296, 0.24763407, -0.14856...
# 9  Bankruptcy Act  [-0.2856197, 0.04948732, 0.3108072, -0.0145417...
# 0   Companies Act  [-0.2655397, 0.16485184, 0.11137321, -0.032306...
# 1   Companies Act  [-0.2850526, 0.081865, 0.22437076, -0.12028224...
# 2   Companies Act  [-0.2584308, 0.21179277, 0.12376887, -0.243688...
# 3   Companies Act  [-0.29690138, 0.19978681, 0.16465591, -0.01841...
# 4   Companies Act  [-0.21195891, 0.15381539, 0.11336231, -0.06637...
#
#    _distance part_title
# 5  19.476759     PART V
# 6  19.494648    PART II
# 7  19.833292     PART V
# 8  20.082418    PART II
# 9  20.151459    PART II
# 0  21.776501        NaN
# 1  21.865467        NaN
# 2  22.435848        NaN
# 3  22.581135        NaN
# 4  22.878630        NaN
# /tmp/ipykernel_13758/3150010096.py:29: UnsupportedWarning: to_df is unsupported as of 0.4.0. Use to_pandas() instead
#   df = table.search(query_vec).limit(self.top_k).to_df()
# [{'chunk': 'section 196; \n(zv) the intervals in which the periodic study, research and audit of the functioning \nand performance of the insolvency professional agencies, insolvency professionals and \ninformation utilities under clause (r), and mechanism for disposal of assets under clause \n(t), of sub-section (1) of',
#   'part_title': 'PART V',
#   'chapter_title': 'CHAPTER VII',
#   'section_title': 'section 196',
#   'page': nan,
#   'source': 'Bankruptcy Act',
#   'score': 19.47675895690918},
#  {'chunk': 'section 62 or such an \nappeal is not time barred under any provision of law for the time being in force; or \n                (iii) where a legal proceeding has been initiated in any court against the decision of \nthe Adjudicating Authority in respect of a resolution plan;]  \n(c) provides for the management of the affairs of the Corporate debtor after \napproval of the resolution plan;  \n(d) The implementation and supervision of the resolution plan;  \n(e) does not contravene any of the provisions of the law for the time being in force \n(f) confirms to such other requirements as may be specified by the Board. \n 1[Explanation. — For the purposes of clause (e), if any approval of shareholders is required under \nthe Companies Act, 2013(18 of 2013) or any other law for the time being in force for the \nimplementation of actions under the resolution plan, such approval shall be deemed to have been given \nand it shall not be a contravention of that Act or law.]  \n(3) The resolution professional shall present to the committee of creditors for its \napproval such resolution plans which confirm the conditions referred to in sub-section (2). \n2[(4) The committee of creditors may approve a resolution plan by a vote of not less \nthan 3[sixty-six] per cent. of voting share of the financial creditors, after considering its \nfeasibility and viability, 4[the manner of distribution proposed, which may take into \naccount the order of priority amongst creditors as laid down in sub-section (1) of',
#   'part_title': 'PART II',
#   'chapter_title': 'CHAPTER II',
#   'section_title': 'section 62',
#   'page': nan,
#   'source': 'Bankruptcy Act',
#   'score': 19.494647979736328},
#  {'chunk': 'section 130; \n\n \n \n \n143 \n \n \n \n \n(w) the manner of sending details of the claims to the bankruptcy trustee and \nother information under sub-sections (1) and (2) of',
#   'part_title': 'PART V',
#   'chapter_title': 'CHAPTER VII',
#   'section_title': 'section 130',
#   'page': nan,
#   'source': 'Bankruptcy Act',
#   'score': 19.83329200744629},
#  {'chunk': 'section 30, it shall by order approve the resolution plan \nwhich shall be binding on the corporate debtor and its employees, members, creditors, \n2[including the Central Government, any State Government or any local authority to whom \na debt in respect of the payment of dues arising under any law for the time being in force, \nsuch as authorities to whom statutory dues are owed,] guarantors and other stakeholders \ninvolved in the resolution plan. \n \n1 Ins. by Act. No. 26 of 2018, sec. 23 (iii) (b) (w.e.f. 6-6-2018). \n2 Ins. by Act No. 26 of 2019, sec. 7 (w.e.f. 16-8-2019). \n\n \n \n \n40 \n \n \n \n \n1[Provided that the Adjudicating Authority shall, before passing an order for approval of \nresolution plan under this sub-section, satisfy that the resolution plan has provisions for its \neffective implementation.] \n \n(2) Where the Adjudicating Authority is satisfied that the resolution plan does not \nconfirm to the requirements referred to in sub-section (1), it may, by an order, reject the \nresolution plan. \n(3)  After the order of approval under sub-section (1), - \n(a) the moratorium order passed by the Adjudicating Authority under',
#   'part_title': 'PART II',
#   'chapter_title': 'CHAPTER II',
#   'section_title': 'section 30',
#   'page': nan,
#   'source': 'Bankruptcy Act',
#   'score': 20.08241844177246},
#  {'chunk': 'section 29A as amended by the Insolvency and \nBankruptcy Code (Amendment) Ordinance, 2018 shall apply to the resolution applicant who has \nnot submitted resolution plan as on the date of commencement of the Insolvency and Bankruptcy \nCode (Amendment) Ordinance, 2018.] \n \n(5) The resolution applicant may attend the meeting of the committee of creditors in \nwhich the resolution plan of the applicant is considered:  \nProvided that the resolution applicant shall not have a right to vote at the meeting of \nthe committee of creditors unless such resolution applicant is also a financial creditor. \n(6) The resolution professional shall submit the resolution plan as approved by the \ncommittee of creditors to the Adjudicating Authority. \n31.  Approval of resolution plan.  - \n  (1)  If the Adjudicating Authority is satisfied that the resolution plan as approved by \nthe committee of creditors under sub-section (4) of',
#   'part_title': 'PART II',
#   'chapter_title': 'CHAPTER II',
#   'section_title': 'section 29A',
#   'page': nan,
#   'source': 'Bankruptcy Act',
#   'score': 20.151458740234375}]

# %%
query_legal_documents(query = "Provided that a company in respect of which such appeal or reference or inquiry stands abated under this clause may make reference to the National Company Law Tribunal under the Insolvency and Bankruptcy Code, 2016 within one hundred and eighty days from the commencement of the Insolvency and Bankruptcy Code, 2016 in accordance with the provisions of the Insolvency and Bankruptcy Code, 2016:")
# Out:
#                        id                                              chunk  \
# 5  bankruptcy_section_449  section 4, for sub-clause (b), the following s...
# 6  bankruptcy_section_502  section 10E of the Companies Act, 1956 (1 of 1...
# 7   bankruptcy_section_74  section 62 or such an \nappeal is not time bar...
# 0             section_561  section 197. \n3[(b) where the company— \n(i) ...
# 8   bankruptcy_section_35  section \n16. \n(2) The public announcement re...
# 1             section_480  section 10E of the \nCompanies Act, 1956 (1 of...
# 9   bankruptcy_section_82  section 30, it shall by order approve the reso...
# 2              section_20  section 2 of the Company Secretaries Act, 1980...
# 3             section_406  section 232 or otherwise, the Tribunal may at ...
# 4             section_204  section 3 of the \nChartered Accountants Act, ...
#
#   section_title                                      chapter_title  page  \
# 5     section 4                                        CHAPTER VII   NaN
# 6   section 10E                                        CHAPTER VII   NaN
# 7    section 62                                         CHAPTER II   NaN
# 0   section 197                                       CHAPTER XXIX   NaN
# 8  section \n16                                         CHAPTER II   NaN
# 1   section 10E  Chapter VI of the Finance Act, 2017, shall con...   NaN
# 9    section 30                                         CHAPTER II   NaN
# 2     section 2                                          CHAPTER I   NaN
# 3   section 232                                         CHAPTER XX   NaN
# 4     section 3                                          CHAPTER X   NaN
#
#            source                                          embedding  \
# 5  Bankruptcy Act  [-0.10818748, 0.19423233, 0.11465185, -0.16461...
# 6  Bankruptcy Act  [-0.20549743, 0.21982461, 0.09978008, -0.30433...
# 7  Bankruptcy Act  [-0.27778187, 0.0855561, 0.24868734, -0.072453...
# 0   Companies Act  [-0.2850526, 0.081865, 0.22437076, -0.12028224...
# 8  Bankruptcy Act  [-0.11901541, 0.2478871, 0.1345311, -0.1224178...
# 1   Companies Act  [-0.2584308, 0.21179277, 0.12376887, -0.243688...
# 9  Bankruptcy Act  [-0.09737422, 0.10348296, 0.24763407, -0.14856...
# 2   Companies Act  [-0.08632175, 0.1235214, 0.12416358, -0.106953...
# 3   Companies Act  [-0.29721326, 0.09979376, 0.15950468, -0.21951...
# 4   Companies Act  [-0.2655397, 0.16485184, 0.11137321, -0.032306...
#
#    _distance part_title
# 5   7.000026     PART V
# 6  12.009084     PART V
# 7  12.063343    PART II
# 0  12.370485        NaN
# 8  12.392740    PART II
# 1  12.441352        NaN
# 9  12.739493    PART II
# 2  13.555852        NaN
# 3  14.451132        NaN
# 4  14.529117        NaN
# /tmp/ipykernel_13758/3150010096.py:29: UnsupportedWarning: to_df is unsupported as of 0.4.0. Use to_pandas() instead
#   df = table.search(query_vec).limit(self.top_k).to_df()
# [{'chunk': 'section 4, for sub-clause (b), the following sub-clause shall be substituted, namely—   \n     \n" (b) On such date as may be notified by the Central Government in \nthis behalf, any appeal preferred to the Appellate Authority or any reference made or \ninquiry pending to or before the Board or any proceeding of whatever nature pending \nbefore the Appellate Authority or the Board under the Sick Industrial Companies \n(Special Provisions) Act,1985 (1 of 1986) shall stand abated:  \n \nProvided that a company in respect of which such appeal or reference or inquiry \nstands abated under this clause may make reference to the National Company Law \nTribunal under the Insolvency and Bankruptcy Code, 2016 within one hundred and \neighty days from the commencement of the Insolvency and Bankruptcy Code, 2016 in \naccordance with the provisions of the Insolvency and Bankruptcy Code, 2016:  \n \nProvided further that no fees shall be payable for making such reference under \nInsolvency and Bankruptcy Code, 2016 by a company whose appeal or reference or \ninquiry stands abated under this clause.". \n \n \n \n \n \n \n \n \n \n \nTHE NINTH SCHEDULE \n(See',
#   'part_title': 'PART V',
#   'chapter_title': 'CHAPTER VII',
#   'section_title': 'section 4',
#   'page': nan,
#   'source': 'Bankruptcy Act',
#   'score': 7.000025749206543},
#  {'chunk': 'section 10E of the Companies Act, 1956 (1 of 1956), immediately before \nsuch date shall stand transferred to the Tribunal and the Tribunal shall dispose of such matters, \nproceedings or cases in accordance with the provisions of this Act; \n \n(b) any person aggrieved by any decision or order of the Company Law Board made \nbefore such date may file an appeal to the High Court within sixty days from the date of \ncommunication of the decision or order of the Company Law Board to him on any question of \nlaw arising out of such order: \n \nProvided that the High Court may if it is satisfied that the appellant was prevented by \nsufficient cause from filing an appeal within the said period, allow it to be filed within a further \nperiod not exceeding sixty days; and \n \n(c) all proceedings under the Companies Act, 1956 (1 of 1956), including proceedings \nrelating to arbitration, compromise, arrangements and reconstruction and winding up of \ncompanies, pending immediately before such date before any District Court or High Court, \nshall stand transferred to the Tribunal and the Tribunal may proceed to deal with such \nproceedings from the stage before their transfer: \n  \nProvided that only such proceedings relating to the winding up of companies shall be \ntransferred to the Tribunal that are at a stage as may be prescribed by the Central Government: \n1[Provided further that any party or parties to any proceedings relating to the winding up of \ncompanies pending before any Court immediately before the commencement of the Insolvency \nand Bankruptcy Code (Amendment) Ordinance, 2018, may file an application for transfer of \nsuch proceedings and the Court may by order transfer such proceedings to the Tribunal and the \nproceedings so transferred shall be dealt with by the Tribunal as an application for initiation of \ncorporate insolvency resolution process under the Insolvency and Bankruptcy Code, 2016.] \n \n(2) The Central Government may make rules consistent with the provisions of this Act \nto ensure timely transfer of all matters, proceedings or cases pending before the Company Law \nBoard or the courts, to the Tribunal under this section.” \n35. In',
#   'part_title': 'PART V',
#   'chapter_title': 'CHAPTER VII',
#   'section_title': 'section 10E',
#   'page': nan,
#   'source': 'Bankruptcy Act',
#   'score': 12.00908374786377},
#  {'chunk': 'section 62 or such an \nappeal is not time barred under any provision of law for the time being in force; or \n                (iii) where a legal proceeding has been initiated in any court against the decision of \nthe Adjudicating Authority in respect of a resolution plan;]  \n(c) provides for the management of the affairs of the Corporate debtor after \napproval of the resolution plan;  \n(d) The implementation and supervision of the resolution plan;  \n(e) does not contravene any of the provisions of the law for the time being in force \n(f) confirms to such other requirements as may be specified by the Board. \n 1[Explanation. — For the purposes of clause (e), if any approval of shareholders is required under \nthe Companies Act, 2013(18 of 2013) or any other law for the time being in force for the \nimplementation of actions under the resolution plan, such approval shall be deemed to have been given \nand it shall not be a contravention of that Act or law.]  \n(3) The resolution professional shall present to the committee of creditors for its \napproval such resolution plans which confirm the conditions referred to in sub-section (2). \n2[(4) The committee of creditors may approve a resolution plan by a vote of not less \nthan 3[sixty-six] per cent. of voting share of the financial creditors, after considering its \nfeasibility and viability, 4[the manner of distribution proposed, which may take into \naccount the order of priority amongst creditors as laid down in sub-section (1) of',
#   'part_title': 'PART II',
#   'chapter_title': 'CHAPTER II',
#   'section_title': 'section 62',
#   'page': nan,
#   'source': 'Bankruptcy Act',
#   'score': 12.063343048095703},
#  {'chunk': 'section 197. \n3[(b) where the company— \n(i) is a newly incorporated company, for a period of seven years from the date of its \nincorporation, or \n(ii) is a sick company, for whom a scheme of revival or rehabilitation has been ordered by the \nBoard for Industrial and Financial Reconstruction for a period of five years from the date of \nsanction of scheme of revival, or  \n(iii) is a company in relation to which a resolution plan has been approved by the National \nCompany Law Tribunal under the Insolvency and Bankruptcy Code, 2016 (31 of 2016) for a period \nof five years from the date of such approval,  \nit may pay 4[any remuneration to its managerial persons  2[or other directors]].] \n(c) where remuneration of a managerial person 2[or other director] exceeds the limits in Section II but \nthe remuneration has been fixed by the Board for Industrial and Financial Reconstruction or the \nNational Company Law Tribunal: \nProvided that the limits under this Section shall be applicable subject to meeting all the conditions \nspecified under Section II and the following additional conditions:— \n                                                           \n1. The words “without Central Government approval” omitted by Notification No. S.O. 4822(E), dated 12th September, 2018 \n(w.e.f. 12-9-2018). \n2. Ins. by Notification No. S.O. 1256(E), dated 18th March, 2021 (w.e.f. 18-3-2021). \n3. Subs. by Act 31 of 2016, s. 255 and the Eleventh Schedule, for clause (b) (w.e.f. 15-11-2016). \n4. Subs. by Notification No. S.O. 4822(E), dated 12th September, 2018, for “remuneration up to two times the amount permissible \nunder Section II” (w.e.f. 12-9-2018). \n\n365 \n \n(i) except as provided in para (a) of this Section, the managerial person is not receiving \nremuneration from any other company; \n(ii) the auditor or Company Secretary of the company or where the company has not appointed a \nSecretary, a Secretary in whole-time practice, certifies that all secured creditors and term \nlenders have stated in writing that they have no objection for the appointment of the managerial \nperson 1[or other director] as well as the quantum of remuneration and such certificate is filed \nalong with the return as prescribed under sub-section (4) of',
#   'part_title': nan,
#   'chapter_title': 'CHAPTER XXIX',
#   'section_title': 'section 197',
#   'page': nan,
#   'source': 'Companies Act',
#   'score': 12.370485305786133},
#  {'chunk': 'section \n16. \n(2) The public announcement referred to in clause (b) of sub-section (1) shall be made \nimmediately after the appointment of the interim resolution professional. \n14. Moratorium. - \n  (1) Subject to provisions of sub-sections (2) and (3), on the insolvency commencement \ndate, the Adjudicating Authority shall by order declare moratorium for prohibiting all of \nthe following, namely: -   \n(a) the institution of suits or continuation of pending suits or proceedings against \nthe corporate debtor including execution of any judgement, decree or order in any court \nof law, tribunal, arbitration panel or other authority;   \n \n1 Ins. by Act No. 26 of 2019, sec. 4 (w.e.f. 16-8-2019).  \n2 Ins. by Act No. 26 of 2018, sec. 9 (w.e.f. 6-6-2018). \n\n \n \n \n20 \n \n \n \n(b) transferring, encumbering, alienating or disposing off by the corporate debtor \nany of its assets or any legal right or beneficial interest therein; \n(c) any action to foreclose, recover or enforce any security interest created by the \ncorporate debtor in respect of its property including any action under the Securitisation \nand Reconstruction of Financial Assets and Enforcement of Security Interest Act, 2002 \n(54 of 2002); \n(d) the recovery of any property by an owner or lessor where such property is   \noccupied by or in the possession of the corporate debtor. \n             1[Explanation.-For the purposes of this sub-section, it is hereby clarified that \nnotwithstanding anything contained in any other law for the time being in force, a licence, \npermit, registration, quota, concession, clearance  or a similar grant or right given by the Central \nGovernment, State Government, local authority, sectoral regulator or any other authority \nconstituted under any other law for the time being in force, shall not be suspended or terminated \non the grounds  of insolvency, subject to the condition that there is no default in payment of \ncurrent dues arising for the use or continuation of the license or a similar grant or right during \nmoratorium period;] \n \n(2)  The supply of essential goods or services to the corporate debtor as may be specified \nshall not be terminated or suspended or interrupted during moratorium period. \n 2[(2A) Where the interim resolution professional or resolution professional, as the case \nmay be, considers the supply of goods or services critical to protect and preserve the value \nof the corporate debtor and manage the operations of such corporate debtor as a going \nconcern, then the supply of such goods or services shall not be terminated, suspended or \ninterrupted during the period of moratorium, except where such corporate debtor has not \npaid dues arising from such supply during the moratorium period or in such circumstances \nas may be specified.] \n       \n3[(3) The provisions of sub-section (1) shall not apply to — \n4[(a) such transactions, agreements or other arrangement as may be notified \nby the Central Government in consultation with any financial sector regulator or \nany other authority;] \n(b) a surety in a contract of guarantee to a corporate debtor.] \n \n \n1 Ins. by Act No. 1 of 2020, sec.5 (w.e.f. 28-12-2019). \n2 Ins. by Act No. 1 of 2020, sec.5 (w.e.f. 28-12-2019). \n3 Subs. by Act No. 26 of 2018, sec. 10 (w.e.f. 6-6-2018). Before its substitution, it stood as under: - \n“(3) The provisions of sub-section (1) shall not apply to such transaction as may be notified by the Central Government in \nconsultation with any financial sector regulator.” \n4 Subs. by Act No. 1 of 2020, sec.5 (w.e.f. 28-12-2019). Before substitution, it stood as “such transaction as may be \nnotified by the Central Government in consultation with any financial regulator;”. \n\n \n \n \n21 \n \n \n \n(4) The order of moratorium shall have effect from the date of such order till the \ncompletion of the corporate insolvency resolution process: \n \nProvided that where at any time during the corporate  ...
#   'part_title': 'PART II',
#   'chapter_title': 'CHAPTER II',
#   'section_title': 'section \n16',
#   'page': nan,
#   'source': 'Bankruptcy Act',
#   'score': 12.392740249633789}]

# %%
import lancedb

# Connect to your LanceDB database directory
db = lancedb.connect("./Data")

# Access the table by name
table = db.open_table("BankruptcyAct")

# Fetch the document by ID
doc_id = "bankruptcy_section_449"  # assuming your ID is stored in a column named "id"
results = table.search("").where(f"id = '{doc_id}'").to_list()

# Display result
if results:
    print("Document found:")
    print(results[0])
else:
    print("Document not found.")

# %%
import lancedb
import pyarrow.compute as pc

# Connect to LanceDB
db = lancedb.connect("./Data")

# Open the table
table = db.open_table("BankruptcyAct")

# Load the table into Arrow format
arrow_table = table.to_arrow()

# Define the doc ID
doc_id = "bankruptcy_section_449"

# Filter using pyarrow.compute
mask = pc.equal(arrow_table["id"], doc_id)
filtered_table = arrow_table.filter(mask)

# Convert to list and print
result = filtered_table.to_pylist()
if result:
    print(result[0].keys())
else:
    print("No document found.")
# Out:
# dict_keys(['id', 'chunk', 'section_title', 'chapter_title', 'part_title', 'page', 'source', 'embedding'])
